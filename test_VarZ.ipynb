# %%
from VarZ import ZVar

# %%
path = '/Users/christine/Dropbox/A_Galaxy_Dynamics/AHOAX/Bullock_Johnston_data/Particle_data_with_header/'
pre = 'with_header_halo_lum_'
suf ='.dat'
allhalos = '/Users/christine/Dropbox/A_Galaxy_Dynamics/mockingpy/sat.dat'

# %%
halos = ZVar(path,pre,suf,allhalos)

# %%
hal2 = halos.calc_zvar('02')

# %%
halos.plot_zvar(hal2)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/tt/z9q9vz1x0y907tzlmjs8tvrr0000gn/T/ipykernel_32344/902438010.py in <module>
# ----> 1 halos.plot_zvar(hal2)
#
# ~/Dropbox/A_Galaxy_Dynamics/AHOAX/Variance/VarZ.py in plot_zvar(self, stats)
#     133         ax.plot(np.log10(xdum), np.log10(ydg), '--', c='black')
#     134         ax.plot(np.log10(xdum), np.log10(ysc), '--', c='black')
# --> 135         ax.scatter(np.log10(stats['z_mean']), np.log10(stats['z_var']), )
#     136         ax.scatter(np.log10(self.halomean), np.log10(self.halovar), marker='s', c=self.reverse_msat_stellar, s=60, alpha=0.5)
#     137         ax.set_ylabel('$\sigma^2$')
#
# ~/Dropbox/A_Galaxy_Dynamics/AHOAX/Variance/venv/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
hal2
# Out:
# {'z_mean': Expression = z_mean
#  Length: 113 dtype: float64 (column)
#  -----------------------------------
#    0  0.0448805
#    1  0.0118255
#    2  0.0326149
#    3  0.0240351
#    4  0.0264626
#       ...
#  108  0.0321456
#  109  0.0208644
#  110  0.0407072
#  111   0.184758
#  112  0.0373489,
#  'z_var': Expression = z_var
#  Length: 113 dtype: float64 (column)
#  -----------------------------------
#    0   0.00012153
#    1  2.61241e-05
#    2   0.00020909
#    3   0.00016798
#    4  0.000174947
#        ...
#  108  5.82585e-05
#  109  1.83953e-05
#  110  9.09321e-05
#  111   0.00759496
#  112  5.98725e-05,
#  'cum_z_mean': [0.0025513888806967294,
#   0.004784586836659504,
#   0.005473532598361034,
#   0.005705669616810539,
#   0.00609281203662715,
#   0.006524357409328405,
#   0.006749379719850488,
#   0.006584357149124317,
#   0.007997667295000656,
#   0.00816014594910489,
#   0.008861509028111347,
#   0.008885258846526892,
#   0.009006325733880938,
# ...
